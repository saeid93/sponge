# %% [markdown]
# # Video pipeline with Yolo + Resnet Model

# %%
import os
import sys
from pprint import PrettyPrinter
import matplotlib.pyplot as plt
from typing import Dict, List

pp = PrettyPrinter(indent=4)
from barazmoon.twitter import twitter_workload_generator

# get an absolute path to the directory that contains parent files
__file__ = globals()["_dh"][0]
project_dir = __file__ = globals()["_dh"][0]
sys.path.append(os.path.normpath(os.path.join(project_dir, "..", "..", "..")))

from experiments.utils.constants import FINAL_RESULTS_PATH, FIGURES_PATH
from experiments.utils.parser import AdaptationParser
from experiments.utils.drawing import (
    draw_temporal_final,
    draw_cumulative,
    draw_temporal_final2,
)
import experiments.utils.drawing

# %%
BURSTY = "Bursty"
STEADY_LOW = "Steady Low"
STEADY_HIGH = "Steady High"
FLUCTUATING = "Fluctuating"

series_load_type = {
    1: BURSTY,
    2: BURSTY,
    3: BURSTY,
    # 4: BURSTY,
    5: BURSTY,
    6: STEADY_LOW,
    7: STEADY_LOW,
    8: STEADY_LOW,
    # 9: STEADY_LOW,
    10: STEADY_LOW,
    11: STEADY_HIGH,
    12: STEADY_HIGH,
    13: STEADY_HIGH,
    # 14: STEADY_HIGH,
    15: STEADY_HIGH,
    16: FLUCTUATING,
    17: FLUCTUATING,
    18: FLUCTUATING,
    # 19: FLUCTUATING,
    20: FLUCTUATING,
}
series_names = {
    1: "IPA",
    2: "FA2-low",
    3: "FA2-high",
    # 4: "RIM-low",
    # 5: "RIM-high",
    5: "RIM",
    6: "IPA",
    7: "FA2-low",
    8: "FA2-high",
    # 9: "RIM-low",
    # 10: "RIM-high",
    10: "RIM",
    11: "IPA",
    12: "FA2-low",
    13: "FA2-high",
    # 14: "RIM-low",
    # 15: "RIM-high",
    15: "RIM",
    16: "IPA",
    17: "FA2-low",
    18: "FA2-high",
    # 19: "RIM-low",
    # 20: "RIM-high",
    20: "RIM",
}

metaseries = 14
load_series = {BURSTY: [], STEADY_LOW: [], STEADY_HIGH: [], FLUCTUATING: []}
for serie, load_type in series_load_type.items():
    load_series[load_type].append(serie)

pipeline_name = "video"
series_paths = {
    series: os.path.join(FINAL_RESULTS_PATH, "metaseries", str(metaseries), "series", str(series))
    for series in series_names.keys()
}

loaders = {
    series: AdaptationParser(
        series_path=series_path, model_name="video", type_of="router_pipeline"
    )
    for series, series_path in series_paths.items()
}

# %%
loaders
# Out:
# {1: <experiments.utils.parser.AdaptationParser at 0x7f6337a7aa00>,
#  2: <experiments.utils.parser.AdaptationParser at 0x7f63377abfd0>,
#  3: <experiments.utils.parser.AdaptationParser at 0x7f64086e8dc0>,
#  5: <experiments.utils.parser.AdaptationParser at 0x7f64086d3d60>,
#  6: <experiments.utils.parser.AdaptationParser at 0x7f64086db580>,
#  7: <experiments.utils.parser.AdaptationParser at 0x7f6337a73220>,
#  8: <experiments.utils.parser.AdaptationParser at 0x7f64086d3d00>,
#  10: <experiments.utils.parser.AdaptationParser at 0x7f64086d3490>,
#  11: <experiments.utils.parser.AdaptationParser at 0x7f64086e8fd0>,
#  12: <experiments.utils.parser.AdaptationParser at 0x7f6337a63b50>,
#  13: <experiments.utils.parser.AdaptationParser at 0x7f64086db730>,
#  15: <experiments.utils.parser.AdaptationParser at 0x7f64086db5b0>,
#  16: <experiments.utils.parser.AdaptationParser at 0x7f64086db610>,
#  17: <experiments.utils.parser.AdaptationParser at 0x7f63377bea30>,
#  18: <experiments.utils.parser.AdaptationParser at 0x7f64086e8790>,
#  20: <experiments.utils.parser.AdaptationParser at 0x7f64086e8e20>}

# %%
accuracy_methods = {}
adaptation_intervals = {}
simulation_modes = {}
configs = {}
for series, loader in loaders.items():
    configs_exp = loader.load_configs()
    print(f"series: {series} config:\n")
    config = configs_exp["0.yaml"]
    pp.pprint(config)
    configs[series] = config
    accuracy_methods[series] = config["accuracy_method"]
    adaptation_intervals[series] = config["adaptation_interval"]
    simulation_modes[series] = config["simulation_mode"]
# Out:
# series: 1 config:
#
# {   'accuracy_method': 'sum',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 2,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': None,
#     'batching_cap': 8,
#     'benchmark_duration': 1,
#     'beta': 1,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 10,
#     'gamma': 1e-06,
#     'initial_active_model': ['yolov5n', 'resnet18'],
#     'initial_batch': [1, 1],
#     'initial_cpu_allocation': [1, 1],
#     'initial_replica': [1, 1],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'metadata': 'bursty - ipa - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 7,
#     'mode': 'exponential',
#     'model_name': ['yolo', 'resnet-human'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'image',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'yolov5n',
#                      'node_name': 'yolo',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'resnet18',
#                      'node_name': 'resnet-human',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 2,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'video',
#     'pipeline_name': 'video',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': 20,
#     'profiling_series': [71, 72],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 1,
#     'simulation_mode': False,
#     'sla_factor': 5,
#     'task_name': ['crop', 'classification'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': 0,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1302360',
#                                'start': '1301160'}],
#     'workload_type': 'twitter'}
# series: 2 config:
#
# {   'accuracy_method': 'sum',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 2,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': 'scale',
#     'batching_cap': 8,
#     'benchmark_duration': 1,
#     'beta': 1,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 10,
#     'gamma': 1e-06,
#     'initial_active_model': ['yolov5n', 'resnet18'],
#     'initial_batch': [1, 1],
#     'initial_cpu_allocation': [1, 1],
#     'initial_replica': [1, 1],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'metadata': 'bursty - fa2-low - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 7,
#     'mode': 'exponential',
#     'model_name': ['yolo', 'resnet-human'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'image',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'yolov5n',
#                      'node_name': 'yolo',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'resnet18',
#                      'node_name': 'resnet-human',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 2,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'video',
#     'pipeline_name': 'video',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': 20,
#     'profiling_series': [71, 72],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 2,
#     'simulation_mode': False,
#     'sla_factor': 5,
#     'task_name': ['crop', 'classification'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': 0,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1302360',
#                                'start': '1301160'}],
#     'workload_type': 'twitter'}
# series: 3 config:
#
# {   'accuracy_method': 'sum',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 2,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': 'scale',
#     'batching_cap': 8,
#     'benchmark_duration': 1,
#     'beta': 1,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 10,
#     'gamma': 1e-06,
#     'initial_active_model': ['yolov5s', 'resnet101'],
#     'initial_batch': [1, 1],
#     'initial_cpu_allocation': [1, 1],
#     'initial_replica': [1, 1],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'metadata': 'bursty - fa2-high - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 7,
#     'mode': 'exponential',
#     'model_name': ['yolo', 'resnet-human'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'image',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'yolov5s',
#                      'node_name': 'yolo',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'resnet101',
#                      'node_name': 'resnet-human',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 2,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'video',
#     'pipeline_name': 'video',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': 20,
#     'profiling_series': [71, 72],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 3,
#     'simulation_mode': False,
#     'sla_factor': 5,
#     'task_name': ['crop', 'classification'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': 0,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1302360',
#                                'start': '1301160'}],
#     'workload_type': 'twitter'}
# series: 5 config:
#
# {   'accuracy_method': 'sum',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 2,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': 'switch',
#     'batching_cap': 8,
#     'benchmark_duration': 1,
#     'beta': 1,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 10,
#     'gamma': 1e-06,
#     'initial_active_model': ['yolov5n', 'resnet18'],
#     'initial_batch': [1, 1],
#     'initial_cpu_allocation': [1, 1],
#     'initial_replica': [3, 3],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'metadata': 'bursty - rim-high - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 7,
#     'mode': 'exponential',
#     'model_name': ['yolo', 'resnet-human'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'image',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'yolov5n',
#                      'node_name': 'yolo',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 3,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'resnet18',
#                      'node_name': 'resnet-human',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 3,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 2,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'video',
#     'pipeline_name': 'video',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': 20,
#     'profiling_series': [71, 72],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 5,
#     'simulation_mode': False,
#     'sla_factor': 5,
#     'task_name': ['crop', 'classification'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': 0,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1302360',
#                                'start': '1301160'}],
#     'workload_type': 'twitter'}
# series: 6 config:
#
# {   'accuracy_method': 'sum',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 2,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': None,
#     'batching_cap': 8,
#     'benchmark_duration': 1,
#     'beta': 1,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 10,
#     'gamma': 1e-06,
#     'initial_active_model': ['yolov5n', 'resnet18'],
#     'initial_batch': [1, 1],
#     'initial_cpu_allocation': [1, 1],
#     'initial_replica': [1, 1],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'metadata': 'steady low - ipa - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 7,
#     'mode': 'exponential',
#     'model_name': ['yolo', 'resnet-human'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'image',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'yolov5n',
#                      'node_name': 'yolo',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'resnet18',
#                      'node_name': 'resnet-human',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 2,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'video',
#     'pipeline_name': 'video',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': 20,
#     'profiling_series': [71, 72],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 6,
#     'simulation_mode': False,
#     'sla_factor': 5,
#     'task_name': ['crop', 'classification'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': 0,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1300800',
#                                'start': '1299600'}],
#     'workload_type': 'twitter'}
# series: 7 config:
#
# {   'accuracy_method': 'sum',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 2,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': 'scale',
#     'batching_cap': 8,
#     'benchmark_duration': 1,
#     'beta': 1,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 10,
#     'gamma': 1e-06,
#     'initial_active_model': ['yolov5n', 'resnet18'],
#     'initial_batch': [1, 1],
#     'initial_cpu_allocation': [1, 1],
#     'initial_replica': [1, 1],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'metadata': 'steady low - fa2-low - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 7,
#     'mode': 'exponential',
#     'model_name': ['yolo', 'resnet-human'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'image',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'yolov5n',
#                      'node_name': 'yolo',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'resnet18',
#                      'node_name': 'resnet-human',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 2,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'video',
#     'pipeline_name': 'video',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': 20,
#     'profiling_series': [71, 72],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 7,
#     'simulation_mode': False,
#     'sla_factor': 5,
#     'task_name': ['crop', 'classification'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': 0,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1300800',
#                                'start': '1299600'}],
#     'workload_type': 'twitter'}
# series: 8 config:
#
# {   'accuracy_method': 'sum',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 2,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': 'scale',
#     'batching_cap': 8,
#     'benchmark_duration': 1,
#     'beta': 1,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 10,
#     'gamma': 1e-06,
#     'initial_active_model': ['yolov5s', 'resnet101'],
#     'initial_batch': [1, 1],
#     'initial_cpu_allocation': [1, 1],
#     'initial_replica': [1, 1],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'metadata': 'steady low - fa2-high - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 7,
#     'mode': 'exponential',
#     'model_name': ['yolo', 'resnet-human'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'image',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'yolov5s',
#                      'node_name': 'yolo',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'resnet101',
#                      'node_name': 'resnet-human',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 2,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'video',
#     'pipeline_name': 'video',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': 20,
#     'profiling_series': [71, 72],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 8,
#     'simulation_mode': False,
#     'sla_factor': 5,
#     'task_name': ['crop', 'classification'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': 0,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1300800',
#                                'start': '1299600'}],
#     'workload_type': 'twitter'}
# series: 10 config:
#
# {   'accuracy_method': 'sum',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 2,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': 'switch',
#     'batching_cap': 8,
#     'benchmark_duration': 1,
#     'beta': 1,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 10,
#     'gamma': 1e-06,
#     'initial_active_model': ['yolov5n', 'resnet18'],
#     'initial_batch': [1, 1],
#     'initial_cpu_allocation': [1, 1],
#     'initial_replica': [3, 3],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'metadata': 'steady low - rim-high - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 7,
#     'mode': 'exponential',
#     'model_name': ['yolo', 'resnet-human'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'image',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'yolov5n',
#                      'node_name': 'yolo',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 3,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'resnet18',
#                      'node_name': 'resnet-human',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 3,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 2,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'video',
#     'pipeline_name': 'video',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': 20,
#     'profiling_series': [71, 72],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 10,
#     'simulation_mode': False,
#     'sla_factor': 5,
#     'task_name': ['crop', 'classification'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': 0,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1300800',
#                                'start': '1299600'}],
#     'workload_type': 'twitter'}
# series: 11 config:
#
# {   'accuracy_method': 'sum',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 2,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': None,
#     'batching_cap': 8,
#     'benchmark_duration': 1,
#     'beta': 1,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 10,
#     'gamma': 1e-06,
#     'initial_active_model': ['yolov5n', 'resnet18'],
#     'initial_batch': [1, 1],
#     'initial_cpu_allocation': [1, 1],
#     'initial_replica': [1, 1],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'metadata': 'steady high - ipa - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 7,
#     'mode': 'exponential',
#     'model_name': ['yolo', 'resnet-human'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'image',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'yolov5n',
#                      'node_name': 'yolo',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'resnet18',
#                      'node_name': 'resnet-human',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 2,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'video',
#     'pipeline_name': 'video',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': 20,
#     'profiling_series': [71, 72],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 11,
#     'simulation_mode': False,
#     'sla_factor': 5,
#     'task_name': ['crop', 'classification'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': 0,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1769400',
#                                'start': '1768800'},
#                            {   'damping_factor': 8,
#                                'end': '1769400',
#                                'start': '1768800'}],
#     'workload_type': 'twitter'}
# series: 12 config:
#
# {   'accuracy_method': 'sum',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 2,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': 'scale',
#     'batching_cap': 8,
#     'benchmark_duration': 1,
#     'beta': 1,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 10,
#     'gamma': 1e-06,
#     'initial_active_model': ['yolov5n', 'resnet18'],
#     'initial_batch': [1, 1],
#     'initial_cpu_allocation': [1, 1],
#     'initial_replica': [1, 1],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'metadata': 'steady high - fa2-low - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 7,
#     'mode': 'exponential',
#     'model_name': ['yolo', 'resnet-human'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'image',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'yolov5n',
#                      'node_name': 'yolo',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'resnet18',
#                      'node_name': 'resnet-human',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 2,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'video',
#     'pipeline_name': 'video',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': 20,
#     'profiling_series': [71, 72],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 12,
#     'simulation_mode': False,
#     'sla_factor': 5,
#     'task_name': ['crop', 'classification'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': 0,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1769400',
#                                'start': '1768800'},
#                            {   'damping_factor': 8,
#                                'end': '1769400',
#                                'start': '1768800'}],
#     'workload_type': 'twitter'}
# series: 13 config:
#
# {   'accuracy_method': 'sum',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 2,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': 'scale',
#     'batching_cap': 8,
#     'benchmark_duration': 1,
#     'beta': 1,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 10,
#     'gamma': 1e-06,
#     'initial_active_model': ['yolov5s', 'resnet101'],
#     'initial_batch': [1, 1],
#     'initial_cpu_allocation': [1, 1],
#     'initial_replica': [1, 1],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'metadata': 'steady high, cpu type: compute_cascadelake_r_ib',
#     'metaseries': 7,
#     'mode': 'exponential',
#     'model_name': ['yolo', 'resnet-human'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'image',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'yolov5s',
#                      'node_name': 'yolo',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'resnet101',
#                      'node_name': 'resnet-human',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 2,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'video',
#     'pipeline_name': 'video',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': 20,
#     'profiling_series': [71, 72],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 13,
#     'simulation_mode': False,
#     'sla_factor': 5,
#     'task_name': ['crop', 'classification'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': 0,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1769400',
#                                'start': '1768800'},
#                            {   'damping_factor': 8,
#                                'end': '1769400',
#                                'start': '1768800'}],
#     'workload_type': 'twitter'}
# series: 15 config:
#
# {   'accuracy_method': 'sum',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 2,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': 'switch',
#     'batching_cap': 8,
#     'benchmark_duration': 1,
#     'beta': 1,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 10,
#     'gamma': 1e-06,
#     'initial_active_model': ['yolov5n', 'resnet18'],
#     'initial_batch': [1, 1],
#     'initial_cpu_allocation': [1, 1],
#     'initial_replica': [3, 3],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'metadata': 'steady high - rim-high - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 7,
#     'mode': 'exponential',
#     'model_name': ['yolo', 'resnet-human'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'image',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'yolov5n',
#                      'node_name': 'yolo',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 3,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'resnet18',
#                      'node_name': 'resnet-human',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 3,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 2,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'video',
#     'pipeline_name': 'video',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': 20,
#     'profiling_series': [71, 72],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 15,
#     'simulation_mode': False,
#     'sla_factor': 5,
#     'task_name': ['crop', 'classification'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': 0,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1769400',
#                                'start': '1768800'},
#                            {   'damping_factor': 8,
#                                'end': '1769400',
#                                'start': '1768800'}],
#     'workload_type': 'twitter'}
# series: 16 config:
#
# {   'accuracy_method': 'sum',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 2,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': None,
#     'batching_cap': 8,
#     'benchmark_duration': 1,
#     'beta': 1,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 10,
#     'gamma': 1e-06,
#     'initial_active_model': ['yolov5n', 'resnet18'],
#     'initial_batch': [1, 1],
#     'initial_cpu_allocation': [1, 1],
#     'initial_replica': [1, 1],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'metadata': 'fluctuating - ipa - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 7,
#     'mode': 'exponential',
#     'model_name': ['yolo', 'resnet-human'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'image',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'yolov5n',
#                      'node_name': 'yolo',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'resnet18',
#                      'node_name': 'resnet-human',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 2,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'video',
#     'pipeline_name': 'video',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': 20,
#     'profiling_series': [71, 72],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 16,
#     'simulation_mode': False,
#     'sla_factor': 5,
#     'task_name': ['crop', 'classification'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': 0,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1302000',
#                                'start': '1301400'},
#                            {   'damping_factor': 8,
#                                'end': '1309200',
#                                'start': '1308600'}],
#     'workload_type': 'twitter'}
# series: 17 config:
#
# {   'accuracy_method': 'sum',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 2,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': 'scale',
#     'batching_cap': 8,
#     'benchmark_duration': 1,
#     'beta': 1,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 10,
#     'gamma': 1e-06,
#     'initial_active_model': ['yolov5n', 'resnet18'],
#     'initial_batch': [1, 1],
#     'initial_cpu_allocation': [1, 1],
#     'initial_replica': [1, 1],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'metadata': 'fluctuating - fa2-low - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 7,
#     'mode': 'exponential',
#     'model_name': ['yolo', 'resnet-human'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'image',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'yolov5n',
#                      'node_name': 'yolo',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'resnet18',
#                      'node_name': 'resnet-human',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 2,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'video',
#     'pipeline_name': 'video',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': 20,
#     'profiling_series': [71, 72],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 17,
#     'simulation_mode': False,
#     'sla_factor': 5,
#     'task_name': ['crop', 'classification'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': 0,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1302000',
#                                'start': '1301400'},
#                            {   'damping_factor': 8,
#                                'end': '1309200',
#                                'start': '1308600'}],
#     'workload_type': 'twitter'}
# series: 18 config:
#
# {   'accuracy_method': 'sum',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 2,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': 'scale',
#     'batching_cap': 8,
#     'benchmark_duration': 1,
#     'beta': 1,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 10,
#     'gamma': 1e-06,
#     'initial_active_model': ['yolov5s', 'resnet101'],
#     'initial_batch': [1, 1],
#     'initial_cpu_allocation': [1, 1],
#     'initial_replica': [1, 1],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'metadata': 'fluctuating - fa2-high - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 7,
#     'mode': 'exponential',
#     'model_name': ['yolo', 'resnet-human'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'image',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'yolov5s',
#                      'node_name': 'yolo',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'resnet101',
#                      'node_name': 'resnet-human',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 2,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'video',
#     'pipeline_name': 'video',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': 20,
#     'profiling_series': [71, 72],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 18,
#     'simulation_mode': False,
#     'sla_factor': 5,
#     'task_name': ['crop', 'classification'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': 0,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1302000',
#                                'start': '1301400'},
#                            {   'damping_factor': 8,
#                                'end': '1309200',
#                                'start': '1308600'}],
#     'workload_type': 'twitter'}
# series: 20 config:
#
# {   'accuracy_method': 'sum',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 2,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': 'switch',
#     'batching_cap': 8,
#     'benchmark_duration': 1,
#     'beta': 1,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 10,
#     'gamma': 1e-06,
#     'initial_active_model': ['yolov5s', 'resnet101'],
#     'initial_batch': [1, 1],
#     'initial_cpu_allocation': [1, 1],
#     'initial_replica': [3, 3],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'metadata': 'fluctuating - rim-high - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 7,
#     'mode': 'exponential',
#     'model_name': ['yolo', 'resnet-human'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'image',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'yolov5n',
#                      'node_name': 'yolo',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 3,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'resnet18',
#                      'node_name': 'resnet-human',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 3,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 2,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'video',
#     'pipeline_name': 'video',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': 20,
#     'profiling_series': [71, 72],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 20,
#     'simulation_mode': False,
#     'sla_factor': 5,
#     'task_name': ['crop', 'classification'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': 0,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1302000',
#                                'start': '1301400'},
#                            {   'damping_factor': 8,
#                                'end': '1309200',
#                                'start': '1308600'}],
#     'workload_type': 'twitter'}

# %%
# load the sent workload
sent_loads = {}
for series, config in configs.items():
    workload_type = config["workload_type"]
    workload_config = config["workload_config"][0]
    start = workload_config["start"]
    end = workload_config["end"]
    damping_factor = workload_config["damping_factor"]
    sent_loads[series] = twitter_workload_generator(
        days=f"{start}-{end}", damping_factor=damping_factor
    )

# %%
# key_config_df = loader.loader.key_config_mapper()
# display(key_config_df)
# key_config_df.columns
results_all = []
simulation_modes
# Out:
# {1: False,
#  2: False,
#  3: False,
#  5: False,
#  6: False,
#  7: False,
#  8: False,
#  10: False,
#  11: False,
#  12: False,
#  13: False,
#  15: False,
#  16: False,
#  17: False,
#  18: False,
#  20: False}

# %%
adaptation_logs = dict(
    map(lambda l: (l[0], l[1].load_adaptation_log()), loaders.items())
)

# %%
series_changes = {}
for series in series_names.keys():
    series_changes[series] = loaders[series].series_changes(
        adaptation_log=adaptation_logs[series]
    )

# %% [markdown]
# ## Comparing Predicted Load with the Recieved Load

# %%
first_sereis = list(series_changes.keys())[
    0
]  # load should be roughly similar among the series
recieved_load = series_changes[first_sereis]["recieved_load"]
recieved_load_x = [x for x in range(0, len(recieved_load))]
predicted_load = series_changes[first_sereis]["predicted_load"]
predicted_load_x = series_changes[first_sereis]["time_interval"]
sent_load = sent_loads[first_sereis]
sent_load_x = [x for x in range(0, len(sent_loads[first_sereis]))]


plt.figure(figsize=(5, 2))
plt.plot(recieved_load_x, recieved_load, label="recieved_load")
plt.plot(sent_load_x, sent_load, label="sent_load")
plt.plot(predicted_load_x, predicted_load, label="predicted_load")
# TODO add predicted reference load here
plt.legend()
plt.show()

# %%
final_dict = {}
METRIC_TOTAL_CORE_CHANGES = "total_core_changes"
METRIC_ACCURACY_CHANGES = "accuracy_changes"
METRIC_MEASURED_LATENCY = "measured_latency"
METRIC_TIMEOUT_DICS = "timeout_dics"
METRICS = [
    METRIC_TOTAL_CORE_CHANGES,
    METRIC_ACCURACY_CHANGES,
    METRIC_MEASURED_LATENCY,
    METRIC_TIMEOUT_DICS,
]

final_dict["replica_changes"] = {}
final_dict["core_changes"] = {}
for metric in METRICS:
    final_dict[metric] = {}


latency_metric = "p99"  # [min, max, p99]


for series, series_dict in series_changes.items():
    final_dict["replica_changes"][series] = {}
    final_dict["core_changes"][series] = {}
    final_dict[METRIC_TOTAL_CORE_CHANGES][series] = {}
    final_dict[METRIC_ACCURACY_CHANGES][series] = {}

    for node_name, metrics in series_changes[series]["nodes"].items():
        final_dict["replica_changes"][series][node_name] = metrics["replicas"]
        final_dict["core_changes"][series][node_name] = metrics["cpu"]
        final_dict[METRIC_ACCURACY_CHANGES][series][node_name] = metrics["accuracy"]

    timeout_per_second, per_second_results = loaders[
        series
    ].per_second_result_processing()

    metric_columns = list(
        filter(lambda col: latency_metric in col, per_second_results.columns)
    )
    final_dict[METRIC_MEASURED_LATENCY][series] = per_second_results[
        metric_columns
    ].to_dict(orient="list")

    final_dict[METRIC_TIMEOUT_DICS][series] = {"timeout_per_second": timeout_per_second}

    # totals
    final_dict["replica_changes"][series]["total"] = [
        sum(x) for x in zip(*final_dict["replica_changes"][series].values())
    ]
    final_dict["core_changes"][series]["total"] = [
        sum(x) for x in zip(*final_dict["core_changes"][series].values())
    ]
    if accuracy_methods[series] == "sum":
        final_dict[METRIC_ACCURACY_CHANGES][series]["e2e"] = [
            sum(x) for x in zip(*final_dict["accuracy_changes"][series].values())
        ]

    for key in final_dict["replica_changes"][series].keys():
        final_dict[METRIC_TOTAL_CORE_CHANGES][series][key] = [
            x * y
            for x, y in zip(
                final_dict["replica_changes"][series][key],
                final_dict["core_changes"][series][key],
            )
        ]


del final_dict["replica_changes"]
del final_dict["core_changes"]

# %%
METRICS_TO_PLOT = [
    METRIC_TOTAL_CORE_CHANGES,
    METRIC_ACCURACY_CHANGES,
    METRIC_MEASURED_LATENCY,
    METRIC_TIMEOUT_DICS,
]

final_by_load_type = {BURSTY: {}, STEADY_LOW: {}, STEADY_HIGH: {}, FLUCTUATING: {}}

for k in final_by_load_type:
    for m in METRICS_TO_PLOT:
        final_by_load_type[k][m] = {}

for metric in METRICS_TO_PLOT:
    for serie in final_dict[metric].keys():
        final_by_load_type[series_load_type[serie]][metric][
            series_names[serie]
        ] = final_dict[metric][serie]

# %%
import importlib

importlib.reload(experiments.utils.drawing)
selected_experiments = {
    METRIC_TOTAL_CORE_CHANGES: {
        "selection": ["total"],
        "title": "Cost",
        "ylabel": "Cost\n (cores)",
    },
    METRIC_ACCURACY_CHANGES: {
        "selection": ["e2e"],
        "title": "Accuracy",
        "ylabel": "Accuracy",
    },
    METRIC_MEASURED_LATENCY: {
        "selection": [f"e2e_{latency_metric}"],
        "title": "Latency",
        "ylabel": "Latency (s)",
    },
    METRIC_TIMEOUT_DICS: {
        "selection": [f"timeout_per_second"],
        "title": "SLA Violations",
        "ylabel": "SLA\n Violations",
    },
}

serie_color = {"IPA": "#ffff99", "FA2-low": "#a1dab4", "FA2-high": "#41b6c4", "RIM-low": "#2c7fb8", "RIM": "#253494"}

experiments.utils.drawing.draw_temporal_final4(
    final_by_load_type,
    adaptation_interval=adaptation_intervals,
    selected_experiments=selected_experiments,
    serie_color=serie_color,
    # hl_for_metric = {METRIC_MEASURED_LATENCY: {"value": 4, "color": "black", "label": "SLA"}},
    hl_for_metric = {},
    bbox_to_anchor=(0.55, 2.5 * len(METRICS_TO_PLOT) + 1),
    save=True,
    filename=f"{FIGURES_PATH}/metaseries-{metaseries}-{pipeline_name}.pdf",
)
# Out:
# num_works = 4

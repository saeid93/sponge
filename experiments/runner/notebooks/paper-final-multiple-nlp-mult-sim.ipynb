# %%
import os
import sys
import numpy as np
from pprint import PrettyPrinter
import matplotlib.pyplot as plt
from typing import Dict, List
import math

pp = PrettyPrinter(indent=4)
from barazmoon.twitter import twitter_workload_generator

# get an absolute path to the directory that contains parent files
__file__ = globals()["_dh"][0]
project_dir = __file__ = globals()["_dh"][0]
sys.path.append(os.path.normpath(os.path.join(project_dir, "..", "..", "..")))

from experiments.utils.constants import FINAL_RESULTS_PATH, FIGURES_PATH
from experiments.utils.parser import AdaptationParser
from experiments.utils.drawing import (
    draw_temporal_final,
    draw_cumulative,
    draw_temporal_final2,
)
import experiments.utils.drawing

# %%
BURSTY = "Bursty"
STEADY_LOW = "Steady Low"
STEADY_HIGH = "Steady High"
FLUCTUATING = "Fluctuating"

series_load_type = {
    81: BURSTY,
    82: BURSTY,
    83: BURSTY,
    # 24: BURSTY,
    85: BURSTY,
    86: STEADY_LOW,
    87: STEADY_LOW,
    88: STEADY_LOW,
    # 29: STEADY_LOW,
    90: STEADY_LOW,
    91: STEADY_HIGH,
    92: STEADY_HIGH,
    93: STEADY_HIGH,
    # 34: STEADY_HIGH,
    95: STEADY_HIGH,
    96: FLUCTUATING,
    97: FLUCTUATING,
    98: FLUCTUATING,
    # 39: FLUCTUATING,
    100: FLUCTUATING,
}
series_names = {
    81: "IPA",
    82: "FA2-low",
    83: "FA2-high",
    # 24: "RIM-low",
    # 25: "RIM-high",
    85: "RIM",
    86: "IPA",
    87: "FA2-low",
    88: "FA2-high",
    # 29: "RIM-low",
    # 30: "RIM-high",
    90: "RIM",
    91: "IPA",
    92: "FA2-low",
    93: "FA2-high",
    # 34: "RIM-low",
    # 35: "RIM-high",
    95: "RIM",
    96: "IPA",
    97: "FA2-low",
    98: "FA2-high",
    # 39: "RIM-low",
    # 40: "RIM-high",
    100: "RIM",
}

metaseries = 52
load_series = {BURSTY: [], STEADY_LOW: [], STEADY_HIGH: [], FLUCTUATING: []}
for serie, load_type in series_load_type.items():
    load_series[load_type].append(serie)

pipeline_name = "audio-qa"
series_paths = {
    series: os.path.join(
        FINAL_RESULTS_PATH, "metaseries", str(metaseries), "series", str(series)
    )
    for series in series_names.keys()
}

loaders = {
    series: AdaptationParser(
        series_path=series_path, model_name="video", type_of="router_pipeline"
    )
    for series, series_path in series_paths.items()
}

# %%
loaders
# Out:
# {81: <experiments.utils.parser.AdaptationParser at 0x7f2ab5776d90>,
#  82: <experiments.utils.parser.AdaptationParser at 0x7f2ac09b7fa0>,
#  83: <experiments.utils.parser.AdaptationParser at 0x7f2ac0acd6d0>,
#  85: <experiments.utils.parser.AdaptationParser at 0x7f2ab5776c10>,
#  86: <experiments.utils.parser.AdaptationParser at 0x7f2ab58a1190>,
#  87: <experiments.utils.parser.AdaptationParser at 0x7f2ac0b42d30>,
#  88: <experiments.utils.parser.AdaptationParser at 0x7f2ac09eef10>,
#  90: <experiments.utils.parser.AdaptationParser at 0x7f2ab591c190>,
#  91: <experiments.utils.parser.AdaptationParser at 0x7f2ac1204e80>,
#  92: <experiments.utils.parser.AdaptationParser at 0x7f2ac121f4f0>,
#  93: <experiments.utils.parser.AdaptationParser at 0x7f2ac0fe4160>,
#  95: <experiments.utils.parser.AdaptationParser at 0x7f2ac0fe4190>,
#  96: <experiments.utils.parser.AdaptationParser at 0x7f2ac0b8b190>,
#  97: <experiments.utils.parser.AdaptationParser at 0x7f2ac0b729a0>,
#  98: <experiments.utils.parser.AdaptationParser at 0x7f2ab57619d0>,
#  100: <experiments.utils.parser.AdaptationParser at 0x7f2ac0942b20>}

# %%
accuracy_methods = {}
adaptation_intervals = {}
simulation_modes = {}
configs = {}
for series, loader in loaders.items():
    configs_exp = loader.load_configs()
    print(f"series: {series} config:\n")
    config = configs_exp["0.yaml"]
    pp.pprint(config)
    configs[series] = config
    accuracy_methods[series] = config["accuracy_method"]
    adaptation_intervals[series] = config["adaptation_interval"]
    simulation_modes[series] = config["simulation_mode"]
# Out:
# series: 81 config:
#
# {   'accuracy_method': 'multiply',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 10,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': None,
#     'batching_cap': 1,
#     'benchmark_duration': 1,
#     'beta': 0.5,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 5,
#     'drop_limit': 20,
#     'from_storage': [False, False, False],
#     'gamma': 1e-06,
#     'initial_active_model': [   'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                                 'Helsinki-NLP-opus-mt-fr-en',
#                                 'sshleifer-distilbart-xsum-1-1'],
#     'initial_batch': [1, 1, 1],
#     'initial_cpu_allocation': [1, 2, 2],
#     'initial_replica': [1, 1, 1],
#     'latency_margin': 0,
#     'logs_enabled': True,
#     'lowest_model_accuracy': 0.05,
#     'metadata': 'bursty - ipa - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 52,
#     'mode': 'exponential',
#     'model_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                      'node_name': 'nlp-li',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '2',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'Helsinki-NLP-opus-mt-fr-en',
#                      'node_name': 'nlp-trans',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '2',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'sshleifer-distilbart-xsum-1-1',
#                      'node_name': 'nlp-sum',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 3,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'nlp',
#     'pipeline_name': 'nlp',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': [20, 10, 10],
#     'profiling_series': [98, 99, 97],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 81,
#     'simulation_mode': True,
#     'sla_factor': 5,
#     'task_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': -50,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1302360',
#                                'start': '1301160'}],
#     'workload_type': 'twitter'}
# series: 82 config:
#
# {   'accuracy_method': 'multiply',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 10,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': 'scale',
#     'batching_cap': 1,
#     'benchmark_duration': 1,
#     'beta': 0.5,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 20,
#     'from_storage': [False, False, False],
#     'gamma': 1e-06,
#     'initial_active_model': [   'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                                 'Helsinki-NLP-opus-mt-fr-en',
#                                 'sshleifer-distilbart-xsum-1-1'],
#     'initial_batch': [1, 1, 1],
#     'initial_cpu_allocation': [1, 2, 2],
#     'initial_replica': [1, 4, 1],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'lowest_model_accuracy': 0.05,
#     'metadata': 'bursty - fa2-low - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 52,
#     'mode': 'exponential',
#     'model_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                      'node_name': 'nlp-li',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '4',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'Helsinki-NLP-opus-mt-fr-en',
#                      'node_name': 'nlp-trans',
#                      'num_interop_threads': '4',
#                      'num_threads': '4',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '2',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'sshleifer-distilbart-xsum-1-1',
#                      'node_name': 'nlp-sum',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 3,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'nlp',
#     'pipeline_name': 'nlp',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': [20, 10, 10],
#     'profiling_series': [98, 99, 97],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 82,
#     'simulation_mode': True,
#     'sla_factor': 5,
#     'task_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': -50,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1302360',
#                                'start': '1301160'}],
#     'workload_type': 'twitter'}
# series: 83 config:
#
# {   'accuracy_method': 'multiply',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 10,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': 'scale',
#     'batching_cap': 1,
#     'benchmark_duration': 1,
#     'beta': 0.5,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 20,
#     'from_storage': [False, False, False],
#     'gamma': 1e-06,
#     'initial_active_model': [   'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                                 'Helsinki-NLP-opus-mt-tc-big-fr-en',
#                                 'sshleifer-distilbart-xsum-6-6'],
#     'initial_batch': [1, 1, 1],
#     'initial_cpu_allocation': [1, 16, 8],
#     'initial_replica': [1, 1, 1],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'lowest_model_accuracy': 0.05,
#     'metadata': 'bursty - fa2-high - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 52,
#     'mode': 'exponential',
#     'model_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                      'node_name': 'nlp-li',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '16',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'Helsinki-NLP-opus-mt-tc-big-fr-en',
#                      'node_name': 'nlp-trans',
#                      'num_interop_threads': '16',
#                      'num_threads': '16',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '4',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'sshleifer-distilbart-xsum-6-6',
#                      'node_name': 'nlp-sum',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 3,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'nlp',
#     'pipeline_name': 'nlp',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': [20, 10, 10],
#     'profiling_series': [98, 99, 97],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 83,
#     'simulation_mode': True,
#     'sla_factor': 5,
#     'task_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': -57,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1302360',
#                                'start': '1301160'}],
#     'workload_type': 'twitter'}
# series: 85 config:
#
# {   'accuracy_method': 'multiply',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 10,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': 'switch',
#     'batching_cap': 1,
#     'benchmark_duration': 1,
#     'beta': 0.5,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 20,
#     'from_storage': [False, False, False],
#     'gamma': 1e-06,
#     'initial_active_model': [   'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                                 'Helsinki-NLP-opus-mt-fr-en',
#                                 'sshleifer-distilbart-xsum-1-1'],
#     'initial_batch': [1, 1, 1],
#     'initial_cpu_allocation': [1, 2, 2],
#     'initial_replica': [6, 22, 12],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'lowest_model_accuracy': 0.05,
#     'metadata': 'bursty - rim-high - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 52,
#     'mode': 'exponential',
#     'model_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                      'node_name': 'nlp-li',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 6,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '4',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'Helsinki-NLP-opus-mt-fr-en',
#                      'node_name': 'nlp-trans',
#                      'num_interop_threads': '4',
#                      'num_threads': '4',
#                      'replicas': 22,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '2',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'sshleifer-distilbart-xsum-1-1',
#                      'node_name': 'nlp-sum',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 12,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 3,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'nlp',
#     'pipeline_name': 'nlp',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': [20, 10, 10],
#     'profiling_series': [98, 99, 97],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 85,
#     'simulation_mode': True,
#     'sla_factor': 5,
#     'task_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': -50,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1302360',
#                                'start': '1301160'}],
#     'workload_type': 'twitter'}
# series: 86 config:
#
# {   'accuracy_method': 'multiply',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 10,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': None,
#     'batching_cap': 1,
#     'benchmark_duration': 1,
#     'beta': 0.5,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 20,
#     'from_storage': [False, False, False],
#     'gamma': 1e-06,
#     'initial_active_model': [   'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                                 'Helsinki-NLP-opus-mt-fr-en',
#                                 'sshleifer-distilbart-xsum-1-1'],
#     'initial_batch': [1, 1, 1],
#     'initial_cpu_allocation': [1, 2, 2],
#     'initial_replica': [1, 1, 1],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'lowest_model_accuracy': 0.05,
#     'metadata': 'steady low - ipa - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 52,
#     'mode': 'exponential',
#     'model_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                      'node_name': 'nlp-li',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '2',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'Helsinki-NLP-opus-mt-fr-en',
#                      'node_name': 'nlp-trans',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '2',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'sshleifer-distilbart-xsum-1-1',
#                      'node_name': 'nlp-sum',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 3,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'nlp',
#     'pipeline_name': 'nlp',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': [20, 10, 10],
#     'profiling_series': [98, 99, 97],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 86,
#     'simulation_mode': True,
#     'sla_factor': 5,
#     'task_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': -50,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1300800',
#                                'start': '1299600'}],
#     'workload_type': 'twitter'}
# series: 87 config:
#
# {   'accuracy_method': 'multiply',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 10,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': 'scale',
#     'batching_cap': 1,
#     'benchmark_duration': 1,
#     'beta': 0.5,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 20,
#     'from_storage': [False, False, False],
#     'gamma': 1e-06,
#     'initial_active_model': [   'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                                 'Helsinki-NLP-opus-mt-fr-en',
#                                 'sshleifer-distilbart-xsum-1-1'],
#     'initial_batch': [1, 1, 1],
#     'initial_cpu_allocation': [1, 2, 2],
#     'initial_replica': [1, 1, 1],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'lowest_model_accuracy': 0.05,
#     'metadata': 'steady low - fa2-low - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 52,
#     'mode': 'exponential',
#     'model_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                      'node_name': 'nlp-li',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '2',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'Helsinki-NLP-opus-mt-fr-en',
#                      'node_name': 'nlp-trans',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '2',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'sshleifer-distilbart-xsum-1-1',
#                      'node_name': 'nlp-sum',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 3,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'nlp',
#     'pipeline_name': 'nlp',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': [20, 10, 10],
#     'profiling_series': [98, 99, 97],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 87,
#     'simulation_mode': True,
#     'sla_factor': 5,
#     'task_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': -50,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1300800',
#                                'start': '1299600'}],
#     'workload_type': 'twitter'}
# series: 88 config:
#
# {   'accuracy_method': 'multiply',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 10,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': 'scale',
#     'batching_cap': 1,
#     'benchmark_duration': 1,
#     'beta': 0.5,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 20,
#     'from_storage': [False, False, False],
#     'gamma': 1e-06,
#     'initial_active_model': [   'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                                 'Helsinki-NLP-opus-mt-tc-big-fr-en',
#                                 'sshleifer-distilbart-xsum-6-6'],
#     'initial_batch': [1, 1, 1],
#     'initial_cpu_allocation': [1, 16, 8],
#     'initial_replica': [1, 1, 1],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'lowest_model_accuracy': 0.05,
#     'metadata': 'steady low - fa2-high - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 52,
#     'mode': 'exponential',
#     'model_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                      'node_name': 'nlp-li',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '16',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'Helsinki-NLP-opus-mt-tc-big-fr-en',
#                      'node_name': 'nlp-trans',
#                      'num_interop_threads': '16',
#                      'num_threads': '16',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '8',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'sshleifer-distilbart-xsum-6-6',
#                      'node_name': 'nlp-sum',
#                      'num_interop_threads': '8',
#                      'num_threads': '8',
#                      'replicas': 1,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 3,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'nlp',
#     'pipeline_name': 'nlp',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': [20, 10, 10],
#     'profiling_series': [98, 99, 97],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 88,
#     'simulation_mode': True,
#     'sla_factor': 5,
#     'task_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': -57,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1300800',
#                                'start': '1299600'}],
#     'workload_type': 'twitter'}
# series: 90 config:
#
# {   'accuracy_method': 'multiply',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 10,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': 'switch',
#     'batching_cap': 1,
#     'benchmark_duration': 1,
#     'beta': 0.5,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 20,
#     'from_storage': [False, False, False],
#     'gamma': 1e-06,
#     'initial_active_model': [   'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                                 'Helsinki-NLP-opus-mt-fr-en',
#                                 'sshleifer-distilbart-xsum-1-1'],
#     'initial_batch': [1, 1, 1],
#     'initial_cpu_allocation': [1, 2, 2],
#     'initial_replica': [6, 22, 12],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'lowest_model_accuracy': 0.05,
#     'metadata': 'steady low - rim-high - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 52,
#     'mode': 'exponential',
#     'model_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                      'node_name': 'nlp-li',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 6,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '4',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'Helsinki-NLP-opus-mt-fr-en',
#                      'node_name': 'nlp-trans',
#                      'num_interop_threads': '4',
#                      'num_threads': '4',
#                      'replicas': 22,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '2',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'sshleifer-distilbart-xsum-1-1',
#                      'node_name': 'nlp-sum',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 12,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 3,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'nlp',
#     'pipeline_name': 'nlp',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': [20, 10, 10],
#     'profiling_series': [98, 99, 97],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 90,
#     'simulation_mode': True,
#     'sla_factor': 5,
#     'task_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': -50,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1300800',
#                                'start': '1299600'}],
#     'workload_type': 'twitter'}
# series: 91 config:
#
# {   'accuracy_method': 'multiply',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 10,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': None,
#     'batching_cap': 1,
#     'benchmark_duration': 1,
#     'beta': 0.5,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 20,
#     'from_storage': [False, False, False],
#     'gamma': 1e-06,
#     'initial_active_model': [   'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                                 'Helsinki-NLP-opus-mt-fr-en',
#                                 'sshleifer-distilbart-xsum-1-1'],
#     'initial_batch': [1, 1, 1],
#     'initial_cpu_allocation': [1, 2, 2],
#     'initial_replica': [1, 1, 1],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'lowest_model_accuracy': 0.05,
#     'metadata': 'steady high - ipa - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 52,
#     'mode': 'exponential',
#     'model_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                      'node_name': 'nlp-li',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '2',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'Helsinki-NLP-opus-mt-fr-en',
#                      'node_name': 'nlp-trans',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '2',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'sshleifer-distilbart-xsum-1-1',
#                      'node_name': 'nlp-sum',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 3,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'nlp',
#     'pipeline_name': 'nlp',
#     'predictor_margin': 20,
#     'predictor_type': 'lstm',
#     'profiling_load': [20, 10, 10],
#     'profiling_series': [98, 99, 97],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 91,
#     'simulation_mode': True,
#     'sla_factor': 5,
#     'task_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': -50,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1769400',
#                                'start': '1768800'},
#                            {   'damping_factor': 8,
#                                'end': '1769400',
#                                'start': '1768800'}],
#     'workload_type': 'twitter'}
# series: 92 config:
#
# {   'accuracy_method': 'multiply',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 10,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': 'scale',
#     'batching_cap': 1,
#     'benchmark_duration': 1,
#     'beta': 0.5,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 20,
#     'from_storage': [False, False, False],
#     'gamma': 1e-06,
#     'initial_active_model': [   'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                                 'Helsinki-NLP-opus-mt-fr-en',
#                                 'sshleifer-distilbart-xsum-1-1'],
#     'initial_batch': [1, 1, 1],
#     'initial_cpu_allocation': [1, 2, 2],
#     'initial_replica': [1, 4, 1],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'lowest_model_accuracy': 0.05,
#     'metadata': 'steady high - fa2-low - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 52,
#     'mode': 'exponential',
#     'model_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                      'node_name': 'nlp-li',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '4',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'Helsinki-NLP-opus-mt-fr-en',
#                      'node_name': 'nlp-trans',
#                      'num_interop_threads': '4',
#                      'num_threads': '4',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '2',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'sshleifer-distilbart-xsum-1-1',
#                      'node_name': 'nlp-sum',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 3,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'nlp',
#     'pipeline_name': 'nlp',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': [20, 10, 10],
#     'profiling_series': [98, 99, 97],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 92,
#     'simulation_mode': True,
#     'sla_factor': 5,
#     'task_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': -50,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1769400',
#                                'start': '1768800'},
#                            {   'damping_factor': 8,
#                                'end': '1769400',
#                                'start': '1768800'}],
#     'workload_type': 'twitter'}
# series: 93 config:
#
# {   'accuracy_method': 'multiply',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 10,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': 'scale',
#     'batching_cap': 1,
#     'benchmark_duration': 1,
#     'beta': 0.5,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 20,
#     'from_storage': [False, False, False],
#     'gamma': 1e-06,
#     'initial_active_model': [   'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                                 'Helsinki-NLP-opus-mt-tc-big-fr-en',
#                                 'sshleifer-distilbart-xsum-6-6'],
#     'initial_batch': [1, 1, 1],
#     'initial_cpu_allocation': [1, 16, 8],
#     'initial_replica': [1, 1, 1],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'lowest_model_accuracy': 0.05,
#     'metadata': 'steady high - fa2-high - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 52,
#     'mode': 'exponential',
#     'model_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                      'node_name': 'nlp-li',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '16',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'Helsinki-NLP-opus-mt-tc-big-fr-en',
#                      'node_name': 'nlp-trans',
#                      'num_interop_threads': '16',
#                      'num_threads': '16',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '4',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'sshleifer-distilbart-xsum-6-6',
#                      'node_name': 'nlp-sum',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 3,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'nlp',
#     'pipeline_name': 'nlp',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': [20, 10, 10],
#     'profiling_series': [98, 99, 97],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 93,
#     'simulation_mode': True,
#     'sla_factor': 5,
#     'task_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': -57,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1769400',
#                                'start': '1768800'},
#                            {   'damping_factor': 8,
#                                'end': '1769400',
#                                'start': '1768800'}],
#     'workload_type': 'twitter'}
# series: 95 config:
#
# {   'accuracy_method': 'multiply',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 10,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': 'switch',
#     'batching_cap': 1,
#     'benchmark_duration': 1,
#     'beta': 0.5,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 20,
#     'from_storage': [False, False, False],
#     'gamma': 1e-06,
#     'initial_active_model': [   'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                                 'Helsinki-NLP-opus-mt-fr-en',
#                                 'sshleifer-distilbart-xsum-1-1'],
#     'initial_batch': [1, 1, 1],
#     'initial_cpu_allocation': [1, 2, 2],
#     'initial_replica': [6, 22, 12],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'lowest_model_accuracy': 0.05,
#     'metadata': 'steady high - rim-high - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 52,
#     'mode': 'exponential',
#     'model_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                      'node_name': 'nlp-li',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 6,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '4',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'Helsinki-NLP-opus-mt-fr-en',
#                      'node_name': 'nlp-trans',
#                      'num_interop_threads': '4',
#                      'num_threads': '4',
#                      'replicas': 22,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '2',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'sshleifer-distilbart-xsum-1-1',
#                      'node_name': 'nlp-sum',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 12,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 3,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'nlp',
#     'pipeline_name': 'nlp',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': [20, 10, 10],
#     'profiling_series': [98, 99, 97],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 95,
#     'simulation_mode': True,
#     'sla_factor': 5,
#     'task_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': -50,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1769400',
#                                'start': '1768800'},
#                            {   'damping_factor': 8,
#                                'end': '1769400',
#                                'start': '1768800'}],
#     'workload_type': 'twitter'}
# series: 96 config:
#
# {   'accuracy_method': 'multiply',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 10,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': None,
#     'batching_cap': 1,
#     'benchmark_duration': 1,
#     'beta': 0.5,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 20,
#     'from_storage': [False, False, False],
#     'gamma': 1e-06,
#     'initial_active_model': [   'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                                 'Helsinki-NLP-opus-mt-fr-en',
#                                 'sshleifer-distilbart-xsum-1-1'],
#     'initial_batch': [1, 1, 1],
#     'initial_cpu_allocation': [1, 2, 2],
#     'initial_replica': [1, 1, 1],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'lowest_model_accuracy': 0.05,
#     'metadata': 'bursty - ipa - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 52,
#     'mode': 'exponential',
#     'model_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                      'node_name': 'nlp-li',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '2',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'Helsinki-NLP-opus-mt-fr-en',
#                      'node_name': 'nlp-trans',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '2',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'sshleifer-distilbart-xsum-1-1',
#                      'node_name': 'nlp-sum',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 3,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'nlp',
#     'pipeline_name': 'nlp',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': [20, 10, 10],
#     'profiling_series': [98, 99, 97],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 96,
#     'simulation_mode': True,
#     'sla_factor': 5,
#     'task_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': -50,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1302000',
#                                'start': '1301400'},
#                            {   'damping_factor': 8,
#                                'end': '1309200',
#                                'start': '1308600'}],
#     'workload_type': 'twitter'}
# series: 97 config:
#
# {   'accuracy_method': 'multiply',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 10,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': 'scale',
#     'batching_cap': 1,
#     'benchmark_duration': 1,
#     'beta': 0.5,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 20,
#     'from_storage': [False, False, False],
#     'gamma': 1e-06,
#     'initial_active_model': [   'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                                 'Helsinki-NLP-opus-mt-fr-en',
#                                 'sshleifer-distilbart-xsum-1-1'],
#     'initial_batch': [1, 1, 1],
#     'initial_cpu_allocation': [1, 2, 2],
#     'initial_replica': [1, 1, 1],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'lowest_model_accuracy': 0.05,
#     'metadata': 'bursty - fa2-low - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 52,
#     'mode': 'exponential',
#     'model_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                      'node_name': 'nlp-li',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '2',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'Helsinki-NLP-opus-mt-fr-en',
#                      'node_name': 'nlp-trans',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '2',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'sshleifer-distilbart-xsum-1-1',
#                      'node_name': 'nlp-sum',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 3,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'nlp',
#     'pipeline_name': 'nlp',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': [20, 10, 10],
#     'profiling_series': [98, 99, 97],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 97,
#     'simulation_mode': True,
#     'sla_factor': 5,
#     'task_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': -50,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1302000',
#                                'start': '1301400'},
#                            {   'damping_factor': 8,
#                                'end': '1309200',
#                                'start': '1308600'}],
#     'workload_type': 'twitter'}
# series: 98 config:
#
# {   'accuracy_method': 'multiply',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 10,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': 'scale',
#     'batching_cap': 1,
#     'benchmark_duration': 1,
#     'beta': 0.5,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 20,
#     'from_storage': [False, False, False],
#     'gamma': 1e-06,
#     'initial_active_model': [   'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                                 'Helsinki-NLP-opus-mt-tc-big-fr-en',
#                                 'sshleifer-distilbart-xsum-6-6'],
#     'initial_batch': [1, 1, 1],
#     'initial_cpu_allocation': [1, 16, 8],
#     'initial_replica': [1, 1, 1],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'lowest_model_accuracy': 0.05,
#     'metadata': 'bursty - fa2-high - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 52,
#     'mode': 'exponential',
#     'model_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                      'node_name': 'nlp-li',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '16',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'Helsinki-NLP-opus-mt-tc-big-fr-en',
#                      'node_name': 'nlp-trans',
#                      'num_interop_threads': '16',
#                      'num_threads': '16',
#                      'replicas': 1,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '4',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'sshleifer-distilbart-xsum-6-6',
#                      'node_name': 'nlp-sum',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 1,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 3,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'nlp',
#     'pipeline_name': 'nlp',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': [20, 10, 10],
#     'profiling_series': [98, 99, 97],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 98,
#     'simulation_mode': True,
#     'sla_factor': 5,
#     'task_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': -57,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1302000',
#                                'start': '1301400'},
#                            {   'damping_factor': 8,
#                                'end': '1309200',
#                                'start': '1308600'}],
#     'workload_type': 'twitter'}
# series: 100 config:
#
# {   'accuracy_method': 'multiply',
#     'adaptation_interval': 10,
#     'allocation_mode': 'base',
#     'alpha': 10,
#     'backup_predictor_duration': 2,
#     'backup_predictor_type': 'max',
#     'baseline_mode': 'switch',
#     'batching_cap': 1,
#     'benchmark_duration': 1,
#     'beta': 0.5,
#     'central_queue': True,
#     'debug_mode': False,
#     'distrpution_time': 30,
#     'drop_limit': 20,
#     'from_storage': [False, False, False],
#     'gamma': 1e-06,
#     'initial_active_model': [   'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                                 'Helsinki-NLP-opus-mt-fr-en',
#                                 'sshleifer-distilbart-xsum-1-1'],
#     'initial_batch': [1, 1, 1],
#     'initial_cpu_allocation': [1, 2, 2],
#     'initial_replica': [6, 22, 12],
#     'latency_margin': 0,
#     'logs_enabled': False,
#     'lowest_model_accuracy': 0.05,
#     'metadata': 'bursty - rim-high - cpu type: compute_cascadelake_r_ib',
#     'metaseries': 52,
#     'mode': 'exponential',
#     'model_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'monitoring_duration': 2,
#     'nodes': [   {   'cpu_request': '1',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'dinalzein-xlm-roberta-base-finetuned-language-identification',
#                      'node_name': 'nlp-li',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 6,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '4',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'Helsinki-NLP-opus-mt-fr-en',
#                      'node_name': 'nlp-trans',
#                      'num_interop_threads': '4',
#                      'num_threads': '4',
#                      'replicas': 22,
#                      'use_threading': 'True'},
#                  {   'cpu_request': '2',
#                      'data_type': 'text',
#                      'max_batch_size': '1',
#                      'max_batch_time': '1',
#                      'memory_request': '4Gi',
#                      'model_variants': 'sshleifer-distilbart-xsum-1-1',
#                      'node_name': 'nlp-sum',
#                      'num_interop_threads': '1',
#                      'num_threads': '1',
#                      'replicas': 12,
#                      'use_threading': 'True'}],
#     'normalize_accuracy': True,
#     'num_state_limit': 1,
#     'number_tasks': 3,
#     'only_measured_profiles': True,
#     'optimization_method': 'gurobi',
#     'pipeline_folder_name': 'nlp',
#     'pipeline_name': 'nlp',
#     'predictor_margin': 0,
#     'predictor_type': 'lstm',
#     'profiling_load': [20, 10, 10],
#     'profiling_series': [98, 99, 97],
#     'reference_latency': 'p99',
#     'reference_throughput': 'max',
#     'scaling_cap': 100,
#     'series': 100,
#     'simulation_mode': True,
#     'sla_factor': 5,
#     'task_name': ['nlp-li', 'nlp-trans', 'nlp-sum'],
#     'teleport_interval': 0,
#     'teleport_mode': False,
#     'threshold': 4,
#     'throughput_margin': -50,
#     'timeout': 1,
#     'warm_up': False,
#     'workload_config': [   {   'damping_factor': 8,
#                                'end': '1302000',
#                                'start': '1301400'},
#                            {   'damping_factor': 8,
#                                'end': '1309200',
#                                'start': '1308600'}],
#     'workload_type': 'twitter'}

# %%
# load the sent workload
sent_loads = {}
for series, config in configs.items():
    workload_type = config["workload_type"]
    workload_config = config["workload_config"][0]
    start = workload_config["start"]
    end = workload_config["end"]
    damping_factor = workload_config["damping_factor"]
    sent_loads[series] = twitter_workload_generator(
        days=f"{start}-{end}", damping_factor=damping_factor
    )

# %%
# key_config_df = loader.loader.key_config_mapper()
# display(key_config_df)
# key_config_df.columns
results_all = []
simulation_modes
# Out:
# {81: True,
#  82: True,
#  83: True,
#  85: True,
#  86: True,
#  87: True,
#  88: True,
#  90: True,
#  91: True,
#  92: True,
#  93: True,
#  95: True,
#  96: True,
#  97: True,
#  98: True,
#  100: True}

# %%
adaptation_logs = dict(
    map(lambda l: (l[0], l[1].load_adaptation_log()), loaders.items())
)

# %%
series_changes = {}
for series in series_names.keys():
    series_changes[series] = loaders[series].series_changes(
        adaptation_log=adaptation_logs[series]
    )

# %% [markdown]
# ## Comparing Predicted Load with the Recieved Load

# %%
first_sereis = list(series_changes.keys())[
    0
]  # load should be roughly similar among the series
recieved_load = series_changes[first_sereis]["recieved_load"]
recieved_load_x = [x for x in range(0, len(recieved_load))]
predicted_load = series_changes[first_sereis]["predicted_load"]
predicted_load_x = series_changes[first_sereis]["time_interval"]
sent_load = sent_loads[first_sereis]
sent_load_x = [x for x in range(0, len(sent_loads[first_sereis]))]


plt.figure(figsize=(5, 2))
plt.plot(recieved_load_x, recieved_load, label="recieved_load")
plt.plot(sent_load_x, sent_load, label="sent_load")
plt.plot(predicted_load_x, predicted_load, label="predicted_load")
# TODO add predicted reference load here
plt.legend()
plt.show()

# %%
final_dict = {}
METRIC_TOTAL_CORE_CHANGES = "total_core_changes"
METRIC_ACCURACY_CHANGES = "accuracy_changes"
METRIC_MEASURED_LATENCY = "measured_latency"
METRIC_TIMEOUT_DICS = "timeout_dics"
METRICS = [
    METRIC_TOTAL_CORE_CHANGES,
    METRIC_ACCURACY_CHANGES,
    METRIC_MEASURED_LATENCY,
    METRIC_TIMEOUT_DICS,
]

final_dict["replica_changes"] = {}
final_dict["core_changes"] = {}
final_dict[METRIC_TOTAL_CORE_CHANGES] = {}
final_dict[METRIC_ACCURACY_CHANGES] = {}
final_dict[METRIC_MEASURED_LATENCY] = {}
final_dict[METRIC_TIMEOUT_DICS] = {}

latency_metric = "p99"  # [min, max, p99]


final_by_load_type = {BURSTY: {}, STEADY_LOW: {}, STEADY_HIGH: {}, FLUCTUATING: {}}
for k in final_by_load_type:
    for m in METRICS:
        final_by_load_type[k][m] = {}


for series, series_dict in series_changes.items():
    final_dict["replica_changes"][series] = {}
    final_dict["core_changes"][series] = {}
    final_dict[METRIC_TOTAL_CORE_CHANGES][series] = {}
    final_dict[METRIC_ACCURACY_CHANGES][series] = {}

    for node_name, metrics in series_changes[series]["nodes"].items():
        final_dict["replica_changes"][series][node_name] = metrics["replicas"]
        final_dict["core_changes"][series][node_name] = metrics["cpu"]
        final_dict[METRIC_ACCURACY_CHANGES][series][node_name] = metrics["accuracy"]

    # timeout_per_second, per_second_results = loaders[
    #     series
    # ].per_second_result_processing()

    # metric_columns = list(
    #     filter(lambda col: latency_metric in col, per_second_results.columns)
    # )
    # final_dict[METRIC_MEASURED_LATENCY][series] = per_second_results[
    #     metric_columns
    # ].to_dict(orient="list")

    # final_dict[METRIC_TIMEOUT_DICS][series] = {"timeout_per_second": timeout_per_second}

    final_dict["replica_changes"][series]["total"] = [
        sum(x) for x in zip(*final_dict["replica_changes"][series].values())
    ]
    final_dict["core_changes"][series]["total"] = [
        sum(x) for x in zip(*final_dict["core_changes"][series].values())
    ]
    if accuracy_methods[series] == "multiply":
        final_dict[METRIC_ACCURACY_CHANGES][series]["e2e"] = [
            math.prod(x) for x in zip(*final_dict["accuracy_changes"][series].values())
        ]

    for key in final_dict["replica_changes"][series].keys():
        if key != "total":
            final_dict[METRIC_TOTAL_CORE_CHANGES][series][key] = [
                x * y
                for x, y in zip(
                    final_dict["replica_changes"][series][key],
                    final_dict["core_changes"][series][key],
                )
            ]
    total = np.zeros(
        len(list(final_dict[METRIC_TOTAL_CORE_CHANGES][series].values())[0])
    )
    for key, series_value in final_dict[METRIC_TOTAL_CORE_CHANGES][series].items():
        total += np.array(series_value)
    final_dict[METRIC_TOTAL_CORE_CHANGES][series]["total"] = total.tolist()


del final_dict["replica_changes"]
del final_dict["core_changes"]


for metric in METRICS:
    for serie in final_dict[metric].keys():
        final_by_load_type[series_load_type[serie]][metric][
            series_names[serie]
        ] = final_dict[metric][serie]

# %%
METRICS_TO_PLOT = [
    METRIC_TOTAL_CORE_CHANGES,
    METRIC_ACCURACY_CHANGES,
    # METRIC_MEASURED_LATENCY,
    # METRIC_TIMEOUT_DICS,
]

final_by_load_type = {BURSTY: {}, STEADY_LOW: {}, STEADY_HIGH: {}, FLUCTUATING: {}}

for k in final_by_load_type:
    for m in METRICS_TO_PLOT:
        final_by_load_type[k][m] = {}

for metric in METRICS_TO_PLOT:
    for serie in final_dict[metric].keys():
        final_by_load_type[series_load_type[serie]][metric][
            series_names[serie]
        ] = final_dict[metric][serie]

# %%
import importlib

importlib.reload(experiments.utils.drawing)
selected_experiments = {
    METRIC_TOTAL_CORE_CHANGES: {
        "selection": ["total"],
        "title": "Cost",
        "ylabel": "Cost\n (cores)",
    },
    METRIC_ACCURACY_CHANGES: {
        "selection": ["e2e"],
        "title": "Accuracy",
        "ylabel": "Accuracy",
    },
    METRIC_MEASURED_LATENCY: {
        "selection": [f"e2e_{latency_metric}"],
        "title": "Latency",
        "ylabel": "Latency (s)",
    },
    METRIC_TIMEOUT_DICS: {
        "selection": [f"timeout_per_second"],
        "title": "SLA Violations",
        "ylabel": "SLA\n Violations",
    },
}

# yellow: ffff99

serie_color = {
    "IPA": "#d7191c",
    "FA2-low": "#a1dab4",
    "FA2-high": "#41b6c4",
    "RIM": "#253494",
}

experiments.utils.drawing.draw_temporal_final4(
    final_by_load_type,
    adaptation_interval=adaptation_intervals,
    selected_experiments=selected_experiments,
    serie_color=serie_color,
    hl_for_metric={
        METRIC_MEASURED_LATENCY: {"value": 4, "color": "black", "label": "SLA"}
    },
    bbox_to_anchor=(0.55, 2.5 * len(METRICS_TO_PLOT) + 1.1),
    hspace=0.3,
    save=True,
    filename=f"{FIGURES_PATH}/metaseries-{metaseries}-{pipeline_name}.pdf",
)
# Out:
# num_works = 4

# %%
import pandas as pd
import os
import sys
from pprint import PrettyPrinter
import matplotlib.pyplot as plt
from typing import Dict, List

pp = PrettyPrinter(indent=4)
from barazmoon.twitter import twitter_workload_generator

# get an absolute path to the directory that contains parent files
__file__ = globals()["_dh"][0]
project_dir = __file__ = globals()["_dh"][0]
sys.path.append(os.path.normpath(os.path.join(project_dir, "..", "..", "..")))

from experiments.utils.constants import FINAL_RESULTS_PATH
from experiments.utils.parser import AdaptationParser

# %%
start = 90
end = 140
serieses = list(range(start, end+1))

series_paths = {}
loaders = {}

for series in serieses:
    print(f"series: {series}")
    try:
        series_path = os.path.join(FINAL_RESULTS_PATH, "series", str(series))
        series_paths[series] = series_path
        loaders[series] = AdaptationParser(
            series_path=series_path, model_name="video", type_of="router_pipeline")
    except FileNotFoundError:
        pass
# Out:
# series: 80
# series: 81
# series: 82
# series: 83
# series: 84
# series: 85
# series: 86
# series: 87
# series: 88
# series: 89
# series: 90
# series: 91
# series: 92
# series: 93
# series: 94
# series: 95
# series: 96
# series: 97
# series: 98
# series: 99
# series: 100
# series: 101
# series: 102
# series: 103
# series: 104
# series: 105
# series: 106
# series: 107
# series: 108
# series: 109
# series: 110
# series: 111
# series: 112
# series: 113
# series: 114
# series: 115
# series: 116
# series: 117
# series: 118
# series: 119
# series: 120
# series: 121
# series: 122
# series: 123
# series: 124
# series: 125
# series: 126
# series: 127
# series: 128
# series: 129
# series: 130
# series: 131
# series: 132
# series: 133
# series: 134
# series: 135
# series: 136
# series: 137
# series: 138
# series: 139
# series: 140

# %%
for series, loader in loaders.items():
    configs_exp = loader.load_configs()
    print(f"series {series} metadata:")
    try:
        config = configs_exp['0.yaml']
    except KeyError:
        continue
    # pp.pprint(config)
    print(f"{config['metadata']}")
    try:
        print(f"outcome: {config['outcome']}")
    except KeyError:
        pass
    try:
        print(f"todo: {config['todo']}")
    except KeyError:
        pass
    print("\n")
# Out:
# series 80 metadata:
# repeat of 71 without central queue - old servers
# outcome: shit as 71
#
#
# series 81 metadata:
# repeat of 72 without central queue - old servers
#
#
# series 82 metadata:
# repeat of 73 without central queue - old servers
#
#
# series 83 metadata:
# repeat of 74 without central queue - old servers
#
#
# series 84 metadata:
# repeant of 66 on UC servers - old servers
#
#
# series 85 metadata:
# repeat of 67 on UC servers - old servers
#
#
# series 86 metadata:
# repeat of 68 on UC servers - old servers
#
#
# series 87 metadata:
# repeat of 86 with 5 second adaptation interval
# outcome: seems to have slightly better latency
#
#
# series 89 metadata:
# repeat of 86 with tiple margin
# outcome: * This was a rational test, even with this margin there is a pick at change time
#
#
# series 90 metadata:
# repeat of 88 with 1 second adaptation interval
#
#
# series 91 metadata:
# repeat of 88 with four routers
#
#
# series 92 metadata:
# repeat of 88 with increased router size
#
#
# series 93 metadata:
# repeat of 88 with lower queue times
#
#
# series 94 metadata:
# series 95 metadata:
# repeat of 88 with batch of one to check is it a general problem or queueu problem - changed the code for it
#
#
# series 96 metadata:
# repeat of 88 on the max config of 88 with the same workload
#
#
# series 97 metadata:
# repeat of 96 on the max config of 84 with the same workload
#
#
# series 98 metadata:
# short experiemnt to implement queue
#
#
# series 99 metadata:
# repeat of 85 with router measurement
#
#
# series 100 metadata:
# repeat of 99 with sync queue
#
#
# series 101 metadata:
# shorter experiment aournd the burst for starting root causes
#
#
# series 102 metadata:
# reapet of 101 with the peak load config
#
#
# series 103 metadata:
# even a shorter experiment
#
#
# series 104 metadata:
# repeat of 103 with intervention on 80th timestep
#
#
# series 105 metadata:
# repeat of 103 with intervention on 70th timestep
#
#
# series 106 metadata:
# first experiment with the early exit
#
#
# series 107 metadata:
# second experiment with the early exit
#
#
# series 108 metadata:
# third experiment with the early exit with early exit everywhere on 5 seconds
#
#
# series 109 metadata:
# drop_limit=10
#
#
# series 110 metadata:
# drop_limit=20
#
#
# series 111 metadata:
# first test with teleporting
#
#
# series 112 metadata:
# first test with teleporting without margin
#
#
# series 113 metadata:
# repeat of 111 without teleporting
#
#
# series 114 metadata:
# repeat of 111 without teleporting
#
#
# series 115 metadata:
# first test with teleporting without margin
#
#
# series 116 metadata:
# repeat of 115 with fixed monitoring
#
#
# series 117 metadata:
# repeat of 116 with 30% margin
#
#
# series 118 metadata:
# repeat of 116 with 50% margin
#
#
# series 119 metadata:
# repeat of 116 with 50% margin with dropping
#
#
# series 120 metadata:
# repeat of 116 with 100% margin
#
#
# series 121 metadata:
# repeat of 116 with 100% margin and drop limit of 3
#
#
# series 122 metadata:
# repeat of 97 on 5 min load to use it for later latency experiments
#
#
# series 123 metadata:
# repeat of 97 and 122 on 1 core per contianer allocation as in both experiments containers core allocations were set to 2
#
#
# series 124 metadata:
# repeat of 123 with batch of resnet set to 8 to be completely comparable
#
#
# series 125 metadata:
# repeat of 103, check the effect of only measured profiles
# outcome: no effect
#
#
# series 126 metadata:
# repeat of 103, with p99 as the references
#
#
# series 127 metadata:
# repeat of 103 to make sure about the concolusion
#
#
# series 128 metadata:
# repeat of 126 with 30 second teleport
#
#
# series 129 metadata:
# repeat of 126 with 50 second teleport
# outcome: why drastic teleporting does not return the equvalent result of fixing on the optimal configuration
# todo: 130. do one without margin for references 131. redo 130 with decreased batch time, 132. redo the optimal configuration experiment of 130, 133. do a teleport that jumps to the tested optimal configration of 131 earlier -> if the result is not the same with teleproting then it might be due to short queue time or some problem in the transitioning phase not the problem of not having enough resources
#
#
# series 130 metadata:
# a plain run without any addition on short load
#
#
# series 131 metadata:
# redo 130, a plain run with decreased batch time
# outcome: decreased queue time provides no major improvement
# todo: None
#
#
# series 132 metadata:
# optimal configuration of 129
# outcome: works as expected and there is not problem with the optimal configuration even without any margin
#
#
# series 133 metadata:
# repeat of 130 with 260 seconds margin to jump to the optimal configuration early, this experiment resutls should be similar to the 132 otherwise there is a transitioning problem
# outcome: teleporting is not working but maybe it is because it is not at still at the optimal point, repeating it with less
#
#
# series 134 metadata:
# repeat of 133 to move it on the optimal point
# outcome: there is still a minimal discrepency so try intervention in the next experiment
#
#
# series 135 metadata:
# repeat of 134 to move it on the optimal point with intervention
# outcome: intervention works well so if it is done correctly we will solve the issue
# todo: why it is differnt from the 134 with optimal point
#
#
# series 136 metadata:
# repeat of 134 in separate mode d
# outcome: no relation between separate running
#
#
# series 137 metadata:
# repeat of 135 with intervention
# outcome: I couldnt find the answer why it is not working with intervention
#
#
# series 138 metadata:
# repeat of 130 to observe queues
#
#
# series 139 metadata:
# repeat of 130 to see if there is a problem when using worker between send and recieve loads
#
#
# series 140 metadata:
# a plain run without any addition on short load

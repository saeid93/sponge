# %% [markdown]
# # Video pipeline with Yolo + Resnet Model

# %%
import pandas as pd
import os
import pandas as pd
import sys
from pprint import PrettyPrinter
pp = PrettyPrinter(indent=4)


# get an absolute path to the directory that contains parent files
project_dir = globals()['_dh'][0]
sys.path.append(os.path.normpath(os.path.join(
    project_dir, '..', '..')))

from experiments.utils.constants import (
    PIPELINE_SIMULATION_CONFIGS_PATH,
    PIPELINE_SIMULATION_RESULTS_PATH
)

series = 101
series_path = os.path.join(
    PIPELINE_SIMULATION_RESULTS_PATH, 'series', str(series))

# %%
all_states = pd.read_csv(
    os.path.join(series_path, 'all-states.csv'))
with_constraints = pd.read_csv(
    os.path.join(series_path, 'with-constraints.csv'))
optimal_brute_froce = pd.read_csv(
    os.path.join(series_path, 'optimal-brute-force.csv'))
optimal_gurobi = pd.read_csv(
    os.path.join(series_path, 'optimal-gurobi.csv'))
all_states.columns
# Out:
# Index(['task_0_variant', 'task_0_cpu', 'task_0_gpu', 'task_0_batch',
#        'task_0_replicas', 'task_1_variant', 'task_1_cpu', 'task_1_gpu',
#        'task_1_batch', 'task_1_replicas', 'objective'],
#       dtype='object')

# %%
set(optimal_gurobi['task_0_cpu'])
# Out:
# {1}

# %%
set(optimal_brute_froce['objective'])
# Out:
# {-2.0}

# %%
set(optimal_brute_froce['objective'])
# Out:
# {-2.0}

# %%
optimal_gurobi
# Out:
#    task_0_variant  task_0_cpu  task_0_gpu  task_0_batch  task_0_replicas  \
# 0         yolov5n           1           0          64.0              1.0
# 1         yolov5n           1           0          64.0              1.0
# 2         yolov5n           1           0          64.0              1.0
# 3         yolov5s           1           0          64.0              1.0
# 4         yolov5n           1           0          36.0              1.0
# ..            ...         ...         ...           ...              ...
# 95        yolov5n           1           0           5.0              1.0
# 96        yolov5n           1           0           3.0              1.0
# 97        yolov5n           1           0           2.0              1.0
# 98        yolov5n           1           0          38.0              1.0
# 99        yolov5n           1           0          20.0              1.0
#
#    task_1_variant  task_1_cpu  task_1_gpu  task_1_batch  task_1_replicas  \
# 0       resnet101           1           0           4.0              1.0
# 1        resnet18           1           0           3.0              1.0
# 2        resnet34           1           0           2.0              1.0
# 3        resnet34           1           0           2.0              1.0
# 4       resnet101           1           0           4.0              1.0
# ..            ...         ...         ...           ...              ...
# 95      resnet101           1           0          35.0              1.0
# 96      resnet101           1           0          35.0              1.0
# 97      resnet101           1           0          35.0              1.0
# 98      resnet101           1           0          19.0              1.0
# 99      resnet101           1           0          19.0              1.0
#
#     objective
# 0        -2.0
# 1        -2.0
# 2        -2.0
# 3        -2.0
# 4        -2.0
# ..        ...
# 95       -2.0
# 96       -2.0
# 97       -2.0
# 98       -2.0
# 99       -2.0
#
# [100 rows x 11 columns]

# %% [markdown]
# # Compare results of Gurobi with brute force
# 1. Check if the optimal of both Gurobi and Brute-force have the same results
# 2. Examine the effect of differnt thresholds
# 3.

# %%
# check if all the gurobi results are also present
# in the brute force method -> yes!
# TODO check why all the models are not possible
not_present_rows = []
checker = 0
for index, row in optimal_gurobi.iterrows():
    if (optimal_brute_froce == row).all(axis=1).sum():
        checker += (optimal_brute_froce == row).all(axis=1).sum()
    else:
        not_present_rows.append(row)
checker
# Out:
# 100

# %%
# check if all the gurobi results are also present
# in the brute force method -> yes!
# TODO check why all the models are not possible
not_present_rows = []
checker = 0
for index, row in optimal_gurobi.iterrows():
    if (with_constraints == row).all(axis=1).sum():
        checker += (with_constraints == row).all(axis=1).sum()
    else:
        not_present_rows.append(row)
checker
# Out:
# 100

# %% [markdown]
# # Compare results of Gurobi with brute force
# 1. Check if the optimal of both Gurobi and Brute-force have the same results
# 2. Examine the effect of differnt thresholds
# 3.

# %%
all_states
# Out:
#         task_0_variant  task_0_cpu  task_0_gpu  task_0_batch  task_0_replicas  \
# 0              yolov5n           1           0             1                1
# 1              yolov5n           1           0             1                1
# 2              yolov5n           1           0             1                1
# 3              yolov5n           1           0             1                1
# 4              yolov5n           1           0             1                1
# ...                ...         ...         ...           ...              ...
# 1638395        yolov5x           1           0            64                4
# 1638396        yolov5x           1           0            64                4
# 1638397        yolov5x           1           0            64                4
# 1638398        yolov5x           1           0            64                4
# 1638399        yolov5x           1           0            64                4
#
#         task_1_variant  task_1_cpu  task_1_gpu  task_1_batch  task_1_replicas  \
# 0            resnet101           1           0             1                1
# 1            resnet101           1           0             2                1
# 2            resnet101           1           0             3                1
# 3            resnet101           1           0             4                1
# 4            resnet101           1           0             5                1
# ...                ...         ...         ...           ...              ...
# 1638395       resnet18           1           0            60                4
# 1638396       resnet18           1           0            61                4
# 1638397       resnet18           1           0            62                4
# 1638398       resnet18           1           0            63                4
# 1638399       resnet18           1           0            64                4
#
#          objective
# 0             -2.0
# 1             -2.0
# 2             -2.0
# 3             -2.0
# 4             -2.0
# ...            ...
# 1638395       -8.0
# 1638396       -8.0
# 1638397       -8.0
# 1638398       -8.0
# 1638399       -8.0
#
# [1638400 rows x 11 columns]
